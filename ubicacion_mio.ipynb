# %%
import pandas as pd
import numpy as np

# %%
rawdata = pd.read_csv(r"C:\Users\camil\OneDrive\Escritorio\Curso Data Science\Trabajo Integrador 1\properatti.csv")
rawdata.head()
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# ...

# %%
#Entender que trae cada columna, y renombrarla para que quede mas prolijo

rawdata = pd.read_csv(r"C:\Users\camil\OneDrive\Escritorio\Curso Data Science\Trabajo Integrador 1\properatti.csv")
country = rawdata.groupby(['country_name'])
country.groups.keys() #Podemos ver que solo tenemos datos de Argentina por lo que esta columna no suma nada al analisis.
# Out:
# dict_keys(['Argentina'])

# %%
#cantidad de datos por zona:

zone= rawdata.groupby(['state_name']).size().reset_index(name='property_type').sort_values(by='property_type',ascending=False)
print(zone)

#quisiera calcular el procentaje pero no se comoa
# Out:
#                       state_name  property_type
# 5                Capital Federal          32316
# 0       Bs.As. G.B.A. Zona Norte          25560
# 2         Bs.As. G.B.A. Zona Sur          13952
# 10                       Córdoba          12069
# 24                      Santa Fe          10172
# 3   Buenos Aires Costa Atlántica          10006
# 1       Bs.As. G.B.A. Zona Oeste           9322
# 4          Buenos Aires Interior           2291
# 19                     Río Negro            808
# 18                       Neuquén            733
# 16                       Mendoza            681
# 27                       Tucumán            674
# 9                     Corrientes            583
# 17                      Misiones            464
# 11                    Entre Ríos            369
# 20                         Salta            278
# 8                         Chubut            259
# 22                      San Luis            252
# 14                      La Pampa            157
# ...

# %%
#queremos ver la cantidad de tipos de propiedades x zona
type_per_zone= rawdata.groupby(['state_name','property_type']).property_type.count()
print(type_per_zone)
# Out:
# state_name                property_type
# Bs.As. G.B.A. Zona Norte  PH                 985
#                           apartment        10622
#                           house            13364
#                           store              589
# Bs.As. G.B.A. Zona Oeste  PH                 789
#                                            ...
# Tierra Del Fuego          store                3
# Tucumán                   PH                   4
#                           apartment          425
#                           house              214
#                           store               31
# Name: property_type, Length: 98, dtype: int64
