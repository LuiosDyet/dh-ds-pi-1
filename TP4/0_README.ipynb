# %% [markdown]
# ## Integrantes:
# 1. Camila Coltriani
# 2. Luis Dartayet
# 3. Irania Fuentes
# 4. Jonathan Fichelson
# 5. Ornella Cevoli
# # Trabajo práctico  4: Analisis de los sentimientos en Twitter

# %% [markdown]
# # Introducción
# Las redes sociales como Twitter han demostrado ser excelentes recursos de información sobre muchos eventos que acontecen en el mundo; tienen el poder de cambiar las opiniones de millones de personas siendo especialmente útil para influir en las masas: campañas políticas, cotización de monedas virtuales, publicidad de ventas, entre otros.
# Pensando en esto, se presenta el siguiente objetivo.

# %% [markdown]
# # Objetivo:
# Analizar los sentimientos con la finalidad de predecir el comportamiento de personas y propagar cambios en tiempo real a medida que se desarrolla el evento que se quiere estudiar.
#
# ## Fuente:
# Dataset Kaggle: https://www.kaggle.com/code/paoloripamonti/twitter-sentiment-analysis/input

# %% [markdown]
# # Cómo leer las notebooks

# %% [markdown]
# cada parte del proyecto está en una notebook diferente, para facilitar la lectura y la comprensión del proyecto.
# las partes del proyecto son:
# 1. importación de datos y análisis exploratorio (notebook 1_import_analysis.ipynb)
# 2. preporcesamiento de datos (notebook 2_preprocessing.ipynb)
# 3. modelado, evaluación y exportación del modelado (notebook 3_model.ipynb)
# 4. deploy del modelo (notebook 4_deploy.ipynb)

# %% [markdown]
# es necesario descargar el dataset de kaggle y descomprimirlo en la carpeta `data` y renombrarlo `twitter.csv` para que el notebook 1_import_analysis.ipynb pueda leer los datos.

# %% [markdown]
# Se pueden correr las notebooks para:

# %%
# Busqueda del modelo
# Está comentado porque su ejecución demora mucho tiempo
# %run 3a_models.ipynb

# %%
# Busqueda de los hiperparametros del mejor modelo
# Está comentado porque su ejecución demora mucho tiempo
# %run 3b_chosen_model.ipynb

# %%
# Deploy del modelo
# %run 4_deploy.ipynb
# Out:
# c:\Users\LuisD\anaconda3\envs\dh\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['positive' 'negative' 'positive' 'negative']
#  * Serving Flask app '4_deploy'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit

# %% [markdown]
# y acceder al deploy del modelo en la siguiente dirección: http://localhost:5000/
