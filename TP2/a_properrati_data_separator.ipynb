# %%
# Importamos el dataset limpio

import pandas as pd

df = pd.read_csv('./data/data_limpio_gdf.csv')

df.head()
# Out:
#        municipio                 provincia        lat        lon  \
# 0      Mataderos           Capital Federal -34.661824 -58.508839
# 1      Mataderos           Capital Federal -34.652262 -58.522982
# 2  Vicente López  Bs.As. G.B.A. Zona Norte -34.532957 -58.521782
# 3       Belgrano           Capital Federal -34.559873 -58.443362
# 4       Belgrano           Capital Federal -34.559873 -58.443362
#
#    sup_m2_total  precio_usd       tipo ambientes_cat  precio_usd_por_m2  \
# 0          40.0     62000.0         PH             1        1550.000000
# 1          55.0     72000.0  apartment             2        1309.090909
# 2          78.0    130000.0         PH             3        1666.666667
# 3          40.0    138000.0  apartment             1        3450.000000
# 4          60.0    195000.0  apartment             2        3250.000000
#
#    tipo_cat_code  municipio_cat_code  provincia_cat_code  ambientes_cat_code  \
# 0              0                 194                   5                   1
# 1              1                 194                   5                   2
# 2              0                 360                   0                   3
# 3              1                  25                   5                   1
# 4              1                  25                   5                   2
#
#                                         geometry  precio_usd_por_m2_cat
# 0                POINT (-58.5088387 -34.6618237)                      2
# 1                POINT (-58.5229825 -34.6522615)                      2
# 2  POINT (-58.52178249999999 -34.53295670000001)                      3
# 3                 POINT (-58.443362 -34.5598729)                      8
# 4                 POINT (-58.443362 -34.5598729)                      8

# %%
# Creamos 3 datasets distintos para cada municipio 
#  
# 1. Belgrano
# 2. Almagro
# 3. San Telmo
# 4. Caballito

df_belgrano = df[df['municipio'] == 'Belgrano']
df_almagro = df[df['municipio'] == 'Almagro']
df_santelmo = df[df['municipio'] == 'San Telmo']
df_caballito = df[df['municipio'] == 'Caballito']

# %%
# Guardamos los datasets en archivos csv

df_belgrano.to_csv('./data/data_limpio_gdf_belgrano.csv', index=False)
df_almagro.to_csv('./data/data_limpio_gdf_almagro.csv', index=False)
df_santelmo.to_csv('./data/data_limpio_gdf_santelmo.csv', index=False)
df_caballito.to_csv('./data/data_limpio_gdf_caballito.csv', index=False)

# %%
# df CABA

df_caba = df[df['provincia'] == 'Capital Federal']
df_caba.to_csv('./data/data_limpio_gdf_caba.csv', index=False)
